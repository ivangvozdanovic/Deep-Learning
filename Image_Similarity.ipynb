# %%
# !pip install git+https://github.com/openai/CLIP.git
# !pip install open_clip_torch
# !pip install sentence_transformers
# Out:
# Collecting git+https://github.com/openai/CLIP.git
#   Cloning https://github.com/openai/CLIP.git to /private/var/folders/t2/gx1412nn6d1dph3bm6g7ymc80000gn/T/pip-req-build-9762jd6k
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git /private/var/folders/t2/gx1412nn6d1dph3bm6g7ymc80000gn/T/pip-req-build-9762jd6k
#   Resolved https://github.com/openai/CLIP.git to commit a1d071733d7111c9c014f024669f959182114e33
#   Preparing metadata (setup.py) ... done
# Collecting ftfy (from clip==1.0)
#   Obtaining dependency information for ftfy from https://files.pythonhosted.org/packages/91/f8/dfa32d06cfcbdb76bc46e0f5d69c537de33f4cedb1a15cd4746ab45a6a26/ftfy-6.1.3-py3-none-any.whl.metadata
#   Downloading ftfy-6.1.3-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: regex in /Users/abraham/anaconda3/lib/python3.11/site-packages (from clip==1.0) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/abraham/anaconda3/lib/python3.11/site-packages (from clip==1.0) (4.65.0)
# Requirement already satisfied: torch in /Users/abraham/anaconda3/lib/python3.11/site-packages (from clip==1.0) (2.0.1)
# Requirement already satisfied: torchvision in /Users/abraham/anaconda3/lib/python3.11/site-packages (from clip==1.0) (0.16.0)
# Collecting wcwidth<0.3.0,>=0.2.12 (from ftfy->clip==1.0)
#   Obtaining dependency information for wcwidth<0.3.0,>=0.2.12 from https://files.pythonhosted.org/packages/31/b1/a59de0ad3aabb17523a39804f4c6df3ae87ead053a4e25362ae03d73d03a/wcwidth-0.2.12-py2.py3-none-any.whl.metadata
#   Downloading wcwidth-0.2.12-py2.py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: filelock in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (4.5.0)
# Requirement already satisfied: sympy in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (1.11.1)
# Requirement already satisfied: networkx in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (3.1)
# Requirement already satisfied: jinja2 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (3.1.2)
# Requirement already satisfied: numpy in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torchvision->clip==1.0) (1.24.3)
# Requirement already satisfied: requests in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torchvision->clip==1.0) (2.31.0)
# Collecting torch (from clip==1.0)
#   Obtaining dependency information for torch from https://files.pythonhosted.org/packages/7b/7c/4d8728e6f8dbe2b8af054bd92c290d94c633270443514e3ee4b768125cf9/torch-2.1.0-cp311-none-macosx_11_0_arm64.whl.metadata
#   Using cached torch-2.1.0-cp311-none-macosx_11_0_arm64.whl.metadata (24 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torchvision->clip==1.0) (9.4.0)
# Requirement already satisfied: fsspec in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch->clip==1.0) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from jinja2->torch->clip==1.0) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->torchvision->clip==1.0) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sympy->torch->clip==1.0) (1.3.0)
# Downloading ftfy-6.1.3-py3-none-any.whl (53 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.4/53.4 kB 2.0 MB/s eta 0:00:00
# Using cached torch-2.1.0-cp311-none-macosx_11_0_arm64.whl (59.6 MB)
# Downloading wcwidth-0.2.12-py2.py3-none-any.whl (34 kB)
# Building wheels for collected packages: clip
#   Building wheel for clip (setup.py) ... done
#   Created wheel for clip: filename=clip-1.0-py3-none-any.whl size=1369497 sha256=0abc1b60799c3fb2f065c77382966715d66d5820b2b9f8ee9425264fdfd4df72
#   Stored in directory: /private/var/folders/t2/gx1412nn6d1dph3bm6g7ymc80000gn/T/pip-ephem-wheel-cache-w6asxckq/wheels/3f/7c/a4/9b490845988bf7a4db33674d52f709f088f64392063872eb9a
# Successfully built clip
# Installing collected packages: wcwidth, ftfy, torch, clip
#   Attempting uninstall: wcwidth
#     Found existing installation: wcwidth 0.2.5
#     Uninstalling wcwidth-0.2.5:
#       Successfully uninstalled wcwidth-0.2.5
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1
#     Uninstalling torch-2.0.1:
#       Successfully uninstalled torch-2.0.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spyder 5.4.3 requires pyqt5<5.16, which is not installed.
# spyder 5.4.3 requires pyqtwebengine<5.16, which is not installed.
# functorch 2.0.0 requires torch<2.1,>=2.0, but you have torch 2.1.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 2.1.0 which is incompatible.
# Successfully installed clip-1.0 ftfy-6.1.3 torch-2.1.0 wcwidth-0.2.12
# Collecting open_clip_torch
#   Obtaining dependency information for open_clip_torch from https://files.pythonhosted.org/packages/7c/7f/952fdffa17b15d0c7c51a730860fcf4f4982528ecc753b190dcd46cc944b/open_clip_torch-2.23.0-py3-none-any.whl.metadata
#   Downloading open_clip_torch-2.23.0-py3-none-any.whl.metadata (30 kB)
# Requirement already satisfied: torch>=1.9.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from open_clip_torch) (2.1.0)
# Requirement already satisfied: torchvision in /Users/abraham/anaconda3/lib/python3.11/site-packages (from open_clip_torch) (0.16.0)
# Requirement already satisfied: regex in /Users/abraham/anaconda3/lib/python3.11/site-packages (from open_clip_torch) (2022.7.9)
# Requirement already satisfied: ftfy in /Users/abraham/anaconda3/lib/python3.11/site-packages (from open_clip_torch) (6.1.3)
# Requirement already satisfied: tqdm in /Users/abraham/anaconda3/lib/python3.11/site-packages (from open_clip_torch) (4.65.0)
# Requirement already satisfied: huggingface-hub in /Users/abraham/anaconda3/lib/python3.11/site-packages (from open_clip_torch) (0.15.1)
# Requirement already satisfied: sentencepiece in /Users/abraham/anaconda3/lib/python3.11/site-packages (from open_clip_torch) (0.1.99)
# Requirement already satisfied: protobuf in /Users/abraham/anaconda3/lib/python3.11/site-packages (from open_clip_torch) (4.24.3)
# Collecting timm (from open_clip_torch)
#   Obtaining dependency information for timm from https://files.pythonhosted.org/packages/01/a5/eeb717242343d9ca34e7de554a6c08d96a0cfc7005ece4f847b1753581a6/timm-0.9.12-py3-none-any.whl.metadata
#   Downloading timm-0.9.12-py3-none-any.whl.metadata (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (4.5.0)
# Requirement already satisfied: sympy in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (1.11.1)
# Requirement already satisfied: networkx in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.9.0->open_clip_torch) (2023.4.0)
# Requirement already satisfied: wcwidth<0.3.0,>=0.2.12 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from ftfy->open_clip_torch) (0.2.12)
# Requirement already satisfied: requests in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub->open_clip_torch) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub->open_clip_torch) (6.0)
# Requirement already satisfied: packaging>=20.9 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub->open_clip_torch) (23.0)
# Collecting safetensors (from timm->open_clip_torch)
#   Obtaining dependency information for safetensors from https://files.pythonhosted.org/packages/0c/84/1e59b0594ca421ff308169b0802d72adcce359619925141b69d2ebc89269/safetensors-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading safetensors-0.4.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torchvision->open_clip_torch) (1.24.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torchvision->open_clip_torch) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.9.0->open_clip_torch) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->open_clip_torch) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->open_clip_torch) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->open_clip_torch) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub->open_clip_torch) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.9.0->open_clip_torch) (1.3.0)
# Downloading open_clip_torch-2.23.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 6.5 MB/s eta 0:00:00a 0:00:01m
# Downloading timm-0.9.12-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 26.7 MB/s eta 0:00:0000:0100:01
# Downloading safetensors-0.4.1-cp311-cp311-macosx_11_0_arm64.whl (426 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.3/426.3 kB 24.0 MB/s eta 0:00:00
# Installing collected packages: safetensors, timm, open_clip_torch
# Successfully installed open_clip_torch-2.23.0 safetensors-0.4.1 timm-0.9.12
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (4.29.2)
# Requirement already satisfied: tqdm in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (2.1.0)
# Requirement already satisfied: torchvision in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (0.16.0)
# Requirement already satisfied: numpy in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.24.3)
# Requirement already satisfied: scikit-learn in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.3.0)
# Requirement already satisfied: scipy in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (1.11.3)
# Requirement already satisfied: nltk in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (3.8.1)
# Requirement already satisfied: sentencepiece in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sentence_transformers) (0.15.1)
# Requirement already satisfied: filelock in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.9.0)
# Requirement already satisfied: fsspec in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.4.0)
# Requirement already satisfied: requests in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.0)
# Requirement already satisfied: sympy in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.7.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.2)
# Requirement already satisfied: click in /Users/abraham/anaconda3/lib/python3.11/site-packages (from nltk->sentence_transformers) (8.0.4)
# Requirement already satisfied: joblib in /Users/abraham/anaconda3/lib/python3.11/site-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from scikit-learn->sentence_transformers) (2.2.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from torchvision->sentence_transformers) (9.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /Users/abraham/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125925 sha256=7dd36cd63ac938eb26269b34f17e61a96b26b077679a1347fa9790c6f1cfb1b0
#   Stored in directory: /Users/abraham/Library/Caches/pip/wheels/ff/27/bf/ffba8b318b02d7f691a57084ee154e26ed24d012b0c7805881
# Successfully built sentence_transformers
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-2.2.2

# %%
import torch
import open_clip
import cv2
from sentence_transformers import util
from PIL import Image
# image processing model
device = "cuda" if torch.cuda.is_available() else "cpu"
model, _, preprocess = open_clip.create_model_and_transforms('ViT-B-16-plus-240', pretrained="laion400m_e32")
model.to(device)
def imageEncoder(img):
    img1 = Image.fromarray(img).convert('RGB')
    img1 = preprocess(img1).unsqueeze(0).to(device)
    img1 = model.encode_image(img1)
    return img1
def generateScore(image1, image2):
    test_img = cv2.imread(image1, cv2.IMREAD_UNCHANGED)
    data_img = cv2.imread(image2, cv2.IMREAD_UNCHANGED)
    img1 = imageEncoder(test_img)
    img2 = imageEncoder(data_img)
    cos_scores = util.pytorch_cos_sim(img1, img2)
    score = round(float(cos_scores[0][0])*100, 2)
    return score

# %%
img1=  'test_data/images/content/parrot.jpg'
img2=  'test_data/images/output/foreground/stylized_parrot_fg.png'
print(f"similarity Score: ", round(generateScore(img1, img2), 2))
#similarity Score: 76.77
# Out:
# similarity Score:  75.58
